# %%
import pandas as pd
df = pd.read_csv('C:/Users/Admin/Desktop/temp/Numpy/terrorismData.csv',encoding='utf-8')
df
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
# lets understand the question
# most dangerous city in jaamu and kashmir? it means the city which comes most in the city column is the most dangerous city

df = df[df['State'] == 'Jammu and Kashmir']
# what does value_count does? it returns the value which occurs most in the column with each of their sum in decreasing order
df_list = df['City'].value_counts()
# index does? index[] simply returns the value of specified index []-> if we doesnt write anyhting it simply returns error
city = df_list.index[0]
# values returns the value of that index
count = df_list.values[0]
# returns a boolean value [df['City']==city and last returns true values only df[df['City']==city]
df = df[df['City']==city]

group = df['Group'].value_counts().index[1]
# group

print(city,group,count)
# Out:
# Srinagar Muslim Separatists 657

# %%
import pandas as pd
df = pd.read_csv('C:/Users/Admin/Desktop/temp/Numpy/terrorismData.csv',encoding='utf-8')

# Date: >26 Month == 5,Year == 2014,country == India
a = df[df.Day >= 26]
b = a[a.Year == 2014]
c = b[b.Country == 'India']
ans1 = c[c.Month == 5]
print(ans1)

# month > 5
# Out:
#         Year  Month  Day Country              State      Region  \
# 132468  2014      5   26   India     Andhra Pradesh  South Asia
# 132496  2014      5   26   India        West Bengal  South Asia
# 132502  2014      5   26   India        West Bengal  South Asia
# 132526  2014      5   27   India  Jammu and Kashmir  South Asia
# 132555  2014      5   27   India             Odisha  South Asia
# 132559  2014      5   27   India          Meghalaya  South Asia
# 132600  2014      5   28   India       Chhattisgarh  South Asia
# 132604  2014      5   28   India             Odisha  South Asia
# 132605  2014      5   28   India             Odisha  South Asia
# 132640  2014      5   29   India            Manipur  South Asia
# 132664  2014      5   29   India          Meghalaya  South Asia
# 132673  2014      5   29   India        Maharashtra  South Asia
# 132687  2014      5   30   India       Chhattisgarh  South Asia
# 132748  2014      5   31   India        Maharashtra  South Asia
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('C:/Users/Admin/Desktop/temp/Numpy/terrorismData.csv',encoding='utf-8')

a = df[df.Day>=26]
b = a[a.Year==2014]
c = b[b.Country=='India']
ans1 = c[c.Month>5]

d = df[df.Year==2014]
e = d[d.Country=='India']
ans2 = e[e.Month>5]

f = df[df.Country=='India']
ans3 = f[f.Year>2014]

count = ans1.shape[0] + ans2.shape[0] + ans3.shape[0]

ans1=ans1[ans1.Group!='Unknown']
ans2=ans2[ans2.Group!='Unknown']
ans3=ans3[ans3.Group!='Unknown']

print(count,ans3.Group.describe().top)
# Out:
# 3401 Maoists

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('C:/Users/Admin/Desktop/temp/Numpy/terrorismData.csv',encoding='utf-8')
# year
year = len(set(df['Year']))

df = df[df['Country'] == 'India']
df['Casuality'] = df['Killed'] + df['Wounded']

jk = df[df['State'] == 'Jammu and Kashmir']
# | -> set each bit to 1 if one of them is 1 (all values are true)
rcc = df[(df['State'] == 'Chhattisgarh') | (df['State'] == 'Jharkhand') | (df['State'] == 'Andhra Pradesh') | (df['State'] == 'Odisha')]

jkc = int(np.sum(jk['Casuality']))
rccc = int(np.sum(rcc['Casuality']))

print(jkc//year,rccc//year)
# Out:
# 261 115

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('C:/Users/Admin/Desktop/temp/Numpy/terrorismData.csv',encoding='utf-8')
ans = df['Killed'].max()
df = df[df['Killed'] == df['Killed'].max()]
df1 = df.Country.iloc[0]
df2 = df.Group.iloc[0]
print(int(ans),df1,df2)
# Out:
# 1570 Iraq Islamic State of Iraq and the Levant (ISIL)

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('C:/Users/Admin/Desktop/temp/Numpy/terrorismData.csv',encoding='utf-8')

# Find out the Country with Highest Number of Terror Attack and in which year the most number of terrorist attack happened in that country ?
# Print count of terror attacks as integer value

df_list = df['Country'].value_counts()
country = df_list.index[0]
max_terror = df_list.values[0]

df = df[df['Country'] == country]
year = df['Year'].value_counts().index[0]

print(country,year,max_terror)
# Out:
# Iraq 2014 24636
